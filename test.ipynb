# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/SMU
# Out:
# /content/drive/MyDrive/SMU

# %%
# !git clone https://ddun-nni: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@github.com/ddun-nni/SMU.git
# Out:
# Cloning into 'SMU'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
cd SMU
# Out:
# /content/drive/MyDrive/SMU/SMU

# %%
# !git config --global user.email 'tndus5312@naver.com'
# !git config --global user.name 'ddun-nni'

# %%
# !git add --all

# %%
# !git commit -m 'Hello World'
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
